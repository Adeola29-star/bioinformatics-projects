# %% [markdown]
# --- DELETION MUTATIONS ---

# %% [markdown]
# --- DELETION MUTATION ---

# %%
import random

def deletion_repeated(seq, n):
    seq_list = list(seq)
    
    for i in range(n):
        pos = random.randint(0, len(seq)-1)


# when pop() is assigned a variable, the variable only returns the base that was popped 
# at the picked position not the list of sequence
        
        seq_list.pop(pos)
        
    mutated_seq = "".join(seq_list)
    return seq, mutated_seq

seq = "ATTTTGCTTGCTGGAAA"
n = int(input("Enter the number of mutations to occur:"))

# removed_base = seq_list.pop(pos)
# print(removed bases), this can be used to optionally view the removed bases

print(deletion_repeated(seq,n))
# Out:
# Enter the number of mutations to occur: 1
# ('ATTTTGCTTGCTGGAAA', 'ATTTTGCTGCTGGAAA')
