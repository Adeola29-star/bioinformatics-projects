# %% [markdown]
# Additional Files (Generated & Used Throughout August)
#
# Created multiple test datasets in .txt, .fasta, and .csv formats.
#
# Files served as both input sequences and output results from various scripts.
#
# Some were manually written using file handling, while others were generated automatically via pandas DataFrames and exported to CSV.
#
# These datasets were used to test workflows for mutation simulation, GC analysis, ORF detection, transcription, and translation
