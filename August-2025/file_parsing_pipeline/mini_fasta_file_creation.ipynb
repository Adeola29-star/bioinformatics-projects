# %% [markdown]
# ### Mini FASTA File Creation
# Created a small custom dataset to simulate biological sequences.
#
# The script writes these DNA sequences into a properly formatted FASTA file for testing and validation of parsing, cleaning, transcription, and translation functions in subsequent analyses.

# %%
data = """
>sequence_1
ATGCCGTTA
TTTAGCXTG

>sequence_2
CGGCTTAA
NNNTTAACG"""

with open("fasta2.txt", "w") as file:
    file.write(data.strip())
