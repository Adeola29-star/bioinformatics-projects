# %% [markdown]
# # Creating Codon–Amino Acid–Frequency Dataset
# This script builds on the previous file handling task by adding amino acids to codons and frequencies.
# It saves the data to a file, reads it back, and prepares it for Pandas-based exploration and visualization.

# %%
data = """codon,Aminoacid,Frequency
AUG,M,0.45
GCU,A,0.21
UUU,F,0.31
UGA,Stop,0.00"""

with open("codon_frequency2.csv", "w") as file:
    file.write(data)

# %%
with open("codon_frequency2.csv", "r") as file:
    print(file.read())
# Out:
# codon,Aminoacid,Frequency
# AUG,M,0.45
# GCU,A,0.21
# UUU,F,0.31
# UGA,Stop,0.00
