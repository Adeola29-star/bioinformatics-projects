# %% [markdown]
# # Count number of sequence lines in a File
#
# ## Description
# This notebook shows how to:
# - Open a file
# - Count the number of lines
# - Use loops and file iteration techniques

# %% [markdown]
# Exercise 3
#
# Open the same header.txt file created.
#
# Read all the lines into a list (so you can use them later in your code).
#
# Then, print the number of lines in the file.

# %%
with open("header.txt", "r") as file:
    lines= file.readlines()
    print(len(lines))
# Out:
# 6
