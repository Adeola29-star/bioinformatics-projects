# %% [markdown]
# # Creating, Reading, and Writing a Text File
#
# ## Description
# This notebook covers:
# - Creating a text file
# - Writing data into a file
# - Reading data back from the file
# - Basic file handling and error-free file operations

# %% [raw]
# Exercise 2
#
# Create a new text file named header.txt.
#
# Write the following lines into it exactly (each on its own line):
#
# >seq1
# ATGCTAGC
# >seq2
# TTGCGTAA
# >seq3
# CCGTAAGG
#
# Then, write Python code to:
#
# Open header.txt
#
# Print only the header lines (the lines starting with >)

# %%
with open("header.txt", "w") as wfile:
    wfile.writelines(f">seq1\nATGCTAGC\n>seq2\nTTGCGTAA\n>seq3\nCCGTAAGG\n")

# %%
with open("header.txt", "r") as file:
    for line in file:
        line= line.strip()
        if line.startswith('>'):
            header = line
            print(header)
# Out:
# >seq1
# >seq2
# >seq3
