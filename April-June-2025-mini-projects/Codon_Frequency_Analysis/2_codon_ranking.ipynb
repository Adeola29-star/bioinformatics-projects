# %% [markdown]
# # Codon Ranking
#
# *Objective:*
# Rank codons based on their frequency in RNA sequences.
#
# *Description:*
# This notebook ranks codons by occurrence and helps arrange them based on the frequency and/ alpahabetically
#
#
# *Skills Applied:*
# - Python programming
# - Sorting algorithms
# - Dictionaries and lists
# - Sequence analysis

# %%
# CODON RANKING
# The counts x[1] are in the descending order while the alphabets x[0] are arranged alphabetically within the counts.

def rank_codons():
    sorted_codons= sorted(codon_freq.items(), key= lambda x:(-x[1], x[0]))
    return f" sorted codons : {sorted_codons}"


codon_freq= {
        'AUG': 5,
        'UUU': 8,
        'UAA': 2,
        'UGG': 8,
        'UUC': 3
        }

print(rank_codons())
# Out:
#  sorted codons : [('UGG', 8), ('UUU', 8), ('AUG', 5), ('UUC', 3), ('UAA', 2)]
