# %% [markdown]
# # DNA to RNA Transcription
#
# *Objective:*
# Transcribe DNA sequences into RNA sequences.
#
# *Description:*
# Converts a given DNA sequence to RNA by replacing thymine (T) with uracil (U), simulating transcription.
#
# *Skills Applied:*
# - Python programming
# - String replacement and loops
# - Nucleotide sequence handling

# %%
# DNA to RNA transcription
# Write a function that tkes a DNA string and returns its RNA complement. DNA is transcribed to RNA by 
# replacing every 'T' with 'U'

def transcription(dna_sequence):
    dna = dna_sequence
    RNA = dna.replace('T','U')
    return f"RNA :{RNA}"

dna= input("Enter a dna string:").upper()
result= transcription(user_input)

print(result)
# Out:
# Enter a dna string: aaggggccctttt
# RNA :AAAGGGCCUCUU

# %%
# Another method
def transcription(dna):
    rna= ""
    for base in dna:
        if base == "T":
            rna += "U"
        else:
            rna += base
    return f"RNA : {rna}"

dna = input("Enter a dna sequence:").upper()
print(transcription(dna))
# Out:
# Enter a dna sequence: aaaagggtttttcccc
# RNA : AAAAGGGUUUUUCCCC
